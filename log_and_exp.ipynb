# %%
# Load the data
data = {
    'year': [1971, 1974, 1978, 1982, 1985, 1989, 1993, 1997, 1999, 2002, 2003, 2006, 2008, 2010, 2012, 2014, 2018],
    'count': [2300, 6000, 29000, 120000, 275000, 1200000, 3100000, 7500000, 24000000, 220000000, 410000000, 720000000, 1600000000, 2900000000, 5000000000, 5500000000, 10000000000]
    }

# %%
import pandas as pd
data_set = pd.DataFrame(data)

# %%
data_set
# Out:
#     year        count  count_log
# 0   1971         2300   7.740664
# 1   1974         6000   8.699515
# 2   1978        29000  10.275051
# 3   1982       120000  11.695247
# 4   1985       275000  12.524526
# 5   1989      1200000  13.997832
# 6   1993      3100000  14.946913
# 7   1997      7500000  15.830414
# 8   1999     24000000  16.993564
# 9   2002    220000000  19.209138
# 10  2003    410000000  19.831668
# 11  2006    720000000  20.394762
# 12  2008   1600000000  21.193269
# 13  2010   2900000000  21.787977
# 14  2012   5000000000  22.332704
# 15  2014   5500000000  22.428014
# 16  2018  10000000000  23.025851

# %%
# plotting the data
plt.figure(figsize=(10, 6))
plt.plot(data_exp['year'], data_set['count'], marker='o')
plt.title("Exponential graph")
plt.xlabel("Year")
plt.ylabel("Transistor Count")
plt.grid(True)
plt.show()

# %%
# taking log of count column
import numpy as np
data['count_log'] = np.log(data_set['count'])

# %%
data_set
# Out:
#     year        count  count_log
# 0   1971         2300   7.740664
# 1   1974         6000   8.699515
# 2   1978        29000  10.275051
# 3   1982       120000  11.695247
# 4   1985       275000  12.524526
# 5   1989      1200000  13.997832
# 6   1993      3100000  14.946913
# 7   1997      7500000  15.830414
# 8   1999     24000000  16.993564
# 9   2002    220000000  19.209138
# 10  2003    410000000  19.831668
# 11  2006    720000000  20.394762
# 12  2008   1600000000  21.193269
# 13  2010   2900000000  21.787977
# 14  2012   5000000000  22.332704
# 15  2014   5500000000  22.428014
# 16  2018  10000000000  23.025851

# %%
# plotting the data
plt.figure(figsize=(10, 6))
plt.plot(data_set['year'], data_set['count_log'], marker='o')
plt.title("logarithmic graph")
plt.xlabel("Year")
plt.ylabel("Transistor Count")
plt.grid(True)
plt.show()

# %% [markdown]
# And we can apply linear regression after log of exponentiation curve because
# y = e^x
# y = log(e^x) = x log e = x
# Then we can apply linear regression
